# %% [markdown]
# <a href="https://colab.research.google.com/github/tejpal123456789/Autocorrection-of-words-by-nlp/blob/main/Autocorrection_of_words_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import nltk
import re

# %%
# !git clone https://github.com/amankharwal/Website-data.git
# Out:
# Cloning into 'Website-data'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 246 (delta 4), reused 0 (delta 0), pack-reused 231
# Receiving objects: 100% (246/246), 172.24 MiB | 25.43 MiB/s, done.
# Resolving deltas: 100% (78/78), done.
# Checking out files: 100% (81/81), done.

# %%
path='/content/Website-data/book.txt'
words = []
with open(path, 'r') as f:
    file_name_data = f.read()
    file_name_data=file_name_data.lower()
    words = re.findall('\w+',file_name_data)

# %%
Vocab=set(words)
print(Vocab)
print(len(Vocab))
# Out:
# {'speeding', 'critically', 'demijohn', 'cite', 'busks', 'slopingly', 'spinning', 'barbaric', 'sabbath', 'fountain', 'seething', 'babes', 'reeled', 'clingings', 'retired', 'tattered', 'distances', 'merry', 'distinction', 'barbarians', 'unlighted', 'breathed', 'progeny', 'quaintness', 'future', 'savagery', 'shrivel', 'canvas', 'spiritual', 'endless', 'preserve', 'eddystone', 'suggested', 'twelfth', 'daughters', 'gasps', 'crusts', 'bundle', 'thirds', 'sink', 'billiard', 'meritoque', 'doing', '_hebrew_', 'methodization', 'austrian', 'powdered', 'aught', 'miles', 'promenade', 'sheered', 'bubbles', 'flourish', 'grateful', 'skins', 'shakespeare', 'frobisher', 'storm', 'ren', 'midwifery', 'weakness', 'appoint', 'cleansed', 'adopting', 'reads', 'pious', 'critical', 'infecting', 'whirl', 'scales', 'choked', 'instinctively', 'wandered', 'comfort', 'bubblingly', 'barbed', 'stiffening', 'aspirations', 'blades', 'placing', 'dislocated', 'blighted', 'black', 'loosening', 'modifications', 'result', 
# ...

# %%
print(f"The first ten words in the text are: \n{words[0:10]}")
# Out:
# The first ten words in the text are:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'moby', 'dick', 'or', 'the', 'whale']

# %%
# Counts of the words
from collections import Counter
word_freq_dict = {}  
word_freq_dict = Counter(words)
print(word_freq_dict.most_common()[0:10])
# Out:
# [('the', 14703), ('of', 6742), ('and', 6517), ('a', 4799), ('to', 4707), ('in', 4238), ('that', 3081), ('it', 2534), ('his', 2530), ('i', 2120)]

# %%
from collections import defaultdict
d0=defaultdict(int)
for word in words:
    d0[word]+=1

# %%
d0.items()
# Out:
# dict_items([('the', 14703), ('project', 91), ('gutenberg', 94), ('ebook', 10), ('of', 6742), ('moby', 90), ('dick', 90), ('or', 797), ('whale', 1230), ('by', 1222), ('herman', 4), ('melville', 4), ('this', 1439), ('is', 1751), ('for', 1644), ('use', 49), ('anyone', 6), ('anywhere', 16), ('at', 1335), ('no', 594), ('cost', 4), ('and', 6517), ('with', 1769), ('almost', 197), ('restrictions', 2), ('whatsoever', 7), ('you', 958), ('may', 255), ('copy', 19), ('it', 2534), ('give', 90), ('away', 186), ('re', 18), ('under', 126), ('terms', 33), ('license', 18), ('included', 14), ('online', 4), ('www', 6), ('org', 13), ('title', 8), ('author', 9), ('release', 1), ('date', 4), ('december', 5), ('25', 4), ('2008', 1), ('2701', 4), ('last', 278), ('updated', 2), ('3', 16), ('2017', 1), ('language', 7), ('english', 49), ('character', 15), ('set', 85), ('encoding', 1), ('utf', 1), ('8', 7), ('start', 37), ('produced', 9), ('daniel', 4), ('lazarus', 7), ('jonesey', 2), ('david', 2), ('widger', 2),
# ...

# %% [markdown]
# Relative word frequency

# %%
prob={}
Total=sum(word_freq_dict.values())
for k in word_freq_dict.keys():
    prob[k]=word_freq_dict[k]/Total

# %%
print(prob)
# Out:
# {'the': 0.06603252448767868, 'project': 0.0004086893646452262, 'gutenberg': 0.0004221626404027611, 'ebook': 4.4910919191783095e-05, 'of': 0.030278941719100165, 'moby': 0.0004041982727260479, 'dick': 0.0004041982727260479, 'or': 0.003579400259585113, 'whale': 0.005524043060589321, 'by': 0.005488114325235894, 'herman': 1.796436767671324e-05, 'melville': 1.796436767671324e-05, 'this': 0.006462681271697588, 'is': 0.007863901950481221, 'for': 0.007383355115129142, 'use': 0.0002200635040397372, 'anyone': 2.694655151506986e-05, 'anywhere': 7.185747070685296e-05, 'at': 0.005995607712103043, 'no': 0.002667708599991916, 'cost': 1.796436767671324e-05, 'and': 0.029268446037285047, 'with': 0.00794474160502643, 'almost': 0.000884745108078127, 'restrictions': 8.98218383835662e-06, 'whatsoever': 3.143764343424817e-05, 'you': 0.004302466058572821, 'may': 0.001145228439390469, 'copy': 8.533074646438789e-05, 'it': 0.011380426923197837, 'give': 0.0004041982727260479, 'away': 0.0008353430969671656, 're':
# ...

# %%
import nltk
 
mistake = "ligting"
 
words = ['apple', 'bag', 'drawing', 'listing', 'linking', 'living', 'lighting', 'orange', 'walking', 'zoo']
 
for word in words:
    jd = nltk.jaccard_distance(set(mistake), set(word))
    print(word, jd)
# Out:
# apple 0.875
# bag 0.8571428571428571
# drawing 0.6666666666666666
# listing 0.16666666666666666
# linking 0.3333333333333333
# living 0.3333333333333333
# lighting 0.16666666666666666
# orange 0.7777777777777778
# walking 0.5
# zoo 1.0

# %% [markdown]
# Find Similar word

# %%
 word_freq_dict.keys()
# Out:
# dict_keys(['the', 'project', 'gutenberg', 'ebook', 'of', 'moby', 'dick', 'or', 'whale', 'by', 'herman', 'melville', 'this', 'is', 'for', 'use', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'restrictions', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'away', 're', 'under', 'terms', 'license', 'included', 'online', 'www', 'org', 'title', 'author', 'release', 'date', 'december', '25', '2008', '2701', 'last', 'updated', '3', '2017', 'language', 'english', 'character', 'set', 'encoding', 'utf', '8', 'start', 'produced', 'daniel', 'lazarus', 'jonesey', 'david', 'widger', 'contents', 'etymology', 'extracts', 'supplied', 'a', 'sub', 'librarian', 'chapter', '1', 'loomings', '2', 'carpet', 'bag', 'spouter', 'inn', '4', 'counterpane', '5', 'breakfast', '6', 'street', '7', 'chapel', 'pulpit', '9', 'sermon', '10', 'bosom', 'friend', '11', 'nightgown', '12', 'biographical', '13', 'wheelbarrow', '14', 'nantucket', '15', 'chowder', '16', 'ship', '17', 'ramadan', '18', 'his
# ...

# %%
import nltk
 
mistake = "ligting"
 
words = ['apple', 'bag', 'drawing', 'listing', 'linking', 'living', 'lighting', 'orange', 'walking', 'zoo']
s1=[]
for word in words:
  
    jd = nltk.jaccard_distance(set(mistake), set(word))
    simi=1-jd
    s1.append(simi)

# %%
s1
# Out:
# [0.125,
#  0.1428571428571429,
#  0.33333333333333337,
#  0.8333333333333334,
#  0.6666666666666667,
#  0.6666666666666667,
#  0.8333333333333334,
#  0.2222222222222222,
#  0.5,
#  0.0]

# %%
for word in  word_freq_dict.keys():
    similarity1=[]
    jd = nltk.jaccard_distance(set(input), set(word))
    similarity=1-jd
    similarity1.append(similarity)

# %%
def autocorrection(input):
    input = input.lower()
    if input in Vocab:
        return('Your word seems to be correct')
    else:
     s1=[]
     for word in word_freq_dict.keys():
  
      jd = nltk.jaccard_distance(set(input), set(word))
      similarity=1-jd
      s1.append(similarity)
    df = pd.DataFrame.from_dict(prob, orient='index').reset_index()
    df = df.rename(columns={'index':'Word', 0:'Prob'})
    df['Similarity'] = s1
    output = df.sort_values(['Similarity', 'Prob'], ascending=False).head()
    return(output)

# %%
autocorrection('learing')
# Out:
#               Word      Prob  Similarity
# 2349      learning  0.000027       1.000
# 8590      algerine  0.000004       1.000
# 333       clearing  0.000027       0.875
# 5572     revealing  0.000022       0.875
# 11061  alternating  0.000018       0.875
